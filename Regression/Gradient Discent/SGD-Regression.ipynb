# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import r2_score

# %%
from sklearn.datasets import load_sample_image

# %%
lr=load_sample_image()
lr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 lr=load_sample_image()
#       2 lr
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
# --> 191 params = func_sig.bind(*args, **kwargs)
#     192 params.apply_defaults()
#     194 # ignore self/cls and positional/keyword markers
#
# File c:\Program Files\Python312\Lib\inspect.py:3259, in Signature.bind(self, *args, **kwargs)
#    3254 def bind(self, /, *args, **kwargs):
#    3255     """Get a BoundArguments object, that maps the passed `args`
#    3256     and `kwargs` to the function's signature.  Raises `TypeError`
#    3257     if the passed arguments can not be bound.
#    3258     """
# -> 3259     return self._bind(args, kwargs)
#
# File c:\Program Files\Python312\Lib\inspect.py:3174, in Signature._bind(self, args, kwargs, partial)
#    3172                 msg = 'missing a required{argtype} argument: {arg!r}'
#    3173                 msg = msg.format(arg=param.name, argtype=argtype)
# -> 3174                 raise TypeError(msg) from None
#    3175 else:
#    3176     # We have a positional argument to process
#    3177     try:
#
# TypeError: missing a required argument: 'image_name'

# %%
from sklearn.model_selection import train_test_split
x,y=lr.data,lr.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=2)

# %%
gd=SGDRegressor(max_iter=100,learning_rate='constant')

# %%
gd.fit(x_train,y_train)
# Out:
# C:\Users\PRINCE AGRAWAL\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_stochastic_gradient.py:1575: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDRegressor(learning_rate='constant', max_iter=100)

# %%
y_pred=gd.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4278570106061912
